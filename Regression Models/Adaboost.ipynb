# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split,KFold,GridSearchCV
from sklearn.datasets import load_boston
from sklearn.ensemble import AdaBoostRegressor

# %%
df = load_boston()
X = df.data
y = df.target
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,random_state=42)

# %%
abc = AdaBoostRegressor()
'''
Params
# base_estimator - The base estimator from which the boosted ensemble is built. If None, then the base estimator is DecisionTreeClassifier(max_depth=1)
# n_estimators default=50 The maximum number of estimators at which boosting is terminated. In case of perfect fit, 
                          the learning procedure is stopped early.
#learning_rate, default=1. Learning rate shrinks the contribution of each classifier by learning_rate. 
                           There is a trade-off between learning_rate and n_estimators.
loss{‘linear’, ‘square’, ‘exponential’}, default=’linear’ The loss function to use when updating the weights after each boosting iteration.
'''
abc.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=50, random_state=None)

# %%
print(abc.base_estimator_)
#print(abc.estimators_) #The collection of fitted sub-estimators.
print(abc.estimator_weights_)
print(abc.estimator_errors_)
print(abc.feature_importances_)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=3,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')
# [2.07502508 2.05813535 1.55624797 1.6699721  1.03404282 1.36056037
#  1.76143825 1.69080184 1.94620585 0.74650302 1.01184274 0.89618604
#  1.33162189 1.42644966 0.79637971 1.16360503 1.31029195 1.35871923
#  0.84278558 1.32795318 1.78733487 1.67961949 0.89370275 1.08851745
#  0.68028101 1.09477305 0.80946795 1.28913868 2.17104858 1.40474308
#  1.2904294  0.80726248 1.22230129 0.91130837 1.59911164 1.24533089
#  1.24479195 1.0966896  0.77252608 1.53556196 1.66049138 0.91994624
#  0.80487545 1.08154226 1.14341169 0.5800703  0.61260335 1.33233768
#  2.10708133 1.17579875]
# ...

# %%
# Methods
print(abc.get_params())
print(abc.score(X_train,y_train))
print(abc.predict(X_train))
# Out:
# {'base_estimator': None, 'learning_rate': 1.0, 'loss': 'linear', 'n_estimators': 50, 'random_state': None}
# 0.9168088734581369
# [25.79615385 22.40783133 22.35047619 24.44342105 16.86610169 22.55333333
#  34.0475     11.275      24.03255814 20.54507042 21.48531469 25.43090909
#  23.42857143 22.21983471 45.83050847 19.42947368 19.42947368 20.8483871
#  20.26176471 22.02887324 22.21983471 37.5125     20.80672269 20.05530303
#  22.58684211 25.90784314 35.77894737 24.33884298 14.4875     13.21481481
#  12.36923077 17.5        33.83596491 25.05       17.86544118 13.57755102
#  47.41090909 22.40783133 20.05752212 22.40783133 20.05530303 13.62
#  11.275      29.14090909 27.26031746 19.94666667 16.43931624 14.61680672
#  22.40783133 20.8483871  24.08011364 33.11506849 25.43090909 22.40783133
#  22.40783133 47.41090909 32.68888889 32.68888889 25.78333333 25.52777778
#  17.78727273 41.22439024 21.56742424 29.15730337 23.66275862 20.17352941
# ...
